# %% [markdown]
# # Worksheet 02
#
# Name:  Ruihang Liu
# UID: U49596386
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Have structure first, but will limit flexibility to change stuff.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# We can't predict everything we need for the project. If we define them too early, we might have done extra unnecessary steps (waste time).

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. Go to sleep
# 2. Don't panic, take the time to read the error.
# 3. Re-read the code patiently.

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %% [markdown]
# - Start by trying to put the queen on an empty spot.
# - if this is a valid location according to the rules of 8-Queen, place the queen there and move on to the next spot.
# - if this is not a valid location, remove the 8-queen from the current board and go back to the previous placed queen location.
# - Remove the placed queen and try the next possible location.

# %%
class Board:
    def __init__(self):
        self.board = [["_" for _ in range(8)] for _ in range(8)]

    def __repr__(self):
        res = ""

        for row in self.board:
            for col in row:
                res += col
                res += " "
            res += "\n"
        return res

    def is_legal_row(self,row,col):
        for j in range(len(self.board)):
            if self.board[row][j] == "Q":
                return False
        return True

    def is_legal_col(self,row,col):
        for i in range(len(self.board)):
            if self.board[i][col] == "Q":
                return False
        return True

    def is_on_board(self,row,col):
        return row >= 0 and row < 8 and col >= 0 and col <8

    def is_legal_diag(self,row,col):
        for i in range(len(self.board)):
            if self.is_on_board(row-i, col-i) and self.board[row-i][col-i] == "Q":
                return False
            if self.is_on_board(row-i, col+i) and self.board[row-i][col+i] == "Q":
                return False
            if self.is_on_board(row+i, col-i) and self.board[row+i][col-i] == "Q":
                return False
            if self.is_on_board(row+i, col+i) and self.board[row+i][col+i] == "Q":
                return False
        return True


    def is_legal(self,row,col):
        if not self.is_legal_row(row,col):
            return False
        if not self.is_legal_col(row,col):
             return False
        if not self.is_legal_diag(row,col):
            return False
        return True

    def set_queen_at(self,row,col):
        self.board[row][col] = "Q"

    def unset_queen_on(self,row):
        self.board[row] = ["_" for _ in range(8)]

    def get_queen_on(self,row):
        for col in range(len(self.board)):
            if self.board[row][col] == "Q":
                return col
        raise ValueError("Programming error")

    def search(self):
        row = 0
        col = 0
        nsols = 0

        while row >= 0:
            if row < 8:
                if col >= 8:
                    row -= 1
                    if row >= 0:
                        col = self.get_queen_on(row) + 1
                        self.unset_queen_on(row)
                else:
                    if self.is_legal(row,col):
                        self.set_queen_at(row,col)
                        row += 1
                        col = 0
                    else:
                        col +=1
            else:
                nsols += 1

                print("Found solution number ", nsols)
                print(self)
                row -= 1
                col = self.get_queen_on(row) + 1
                self.unset_queen_on(row)
                
        print("No more solutions")

my_board = Board()
print(my_board.search())
# Out:
# Found solution number  1
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  2
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  3
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  4
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  5
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Found solution number  6
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  7
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  8
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  9
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Found solution number  10
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  11
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  12
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
#
# Found solution number  13
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  14
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  15
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
#
# Found solution number  16
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
#
# Found solution number  17
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  18
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
#
# Found solution number  19
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
#
# Found solution number  20
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
#
# Found solution number  21
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
#
# Found solution number  22
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
#
# Found solution number  23
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
#
# Found solution number  24
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  25
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Found solution number  26
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  27
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  28
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  29
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  30
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
#
# Found solution number  31
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  32
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  33
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
#
# Found solution number  34
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  35
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  36
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  37
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  38
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  39
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
#
# Found solution number  40
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  41
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  42
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
#
# Found solution number  43
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
#
# Found solution number  44
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Found solution number  45
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  46
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  47
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
#
# Found solution number  48
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  49
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  50
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  51
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
#
# Found solution number  52
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
#
# Found solution number  53
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  54
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  55
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  56
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
#
# Found solution number  57
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
#
# Found solution number  58
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  59
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  60
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
#
# Found solution number  61
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
#
# Found solution number  62
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
#
# Found solution number  63
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  64
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  65
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
#
# Found solution number  66
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
#
# Found solution number  67
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  68
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  69
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# Found solution number  70
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  71
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
#
# Found solution number  72
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
#
# Found solution number  73
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  74
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  75
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  76
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
#
# Found solution number  77
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  78
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
#
# Found solution number  79
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  80
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# Found solution number  81
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  82
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  83
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
#
# Found solution number  84
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ Q _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  85
# _ _ _ _ _ _ Q _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  86
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  87
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# Found solution number  88
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# Found solution number  89
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  90
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
#
# Found solution number  91
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
#
# Found solution number  92
# _ _ _ _ _ _ _ Q
# _ _ _ Q _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# No more solutions
# None
