# %% [markdown]
# # Worksheet 03
#
# Name:  Ruihang Liu
# UID: U49596386
#
# ### Topics
#
# - Intro to DS
#
# ### Linear Algebra Review
#
# If you need a linear algebra review, please read through the [following pdf](https://github.com/gallettilance/CS506-Spring2023/raw/main/worksheets/lecture_03_linear_algebra_review.pdf) before next class
#
# ### Intro to Data Science
#
# a) what property must a hypothesis have?

# %% [markdown]
# Need to be testable

# %% [markdown]
# b) what examples would you have wanted to try?

# %% [markdown]
# A. (100, 102, 104)

# %% [markdown]
# c) Poll 1

# %% [markdown]
# A. (100, 102, 104)

# %% [markdown]
# d) Given the hypothesis (x, 2x, 3x), for each of the following, determine whether they are positive or negative examples:
#
# - (2, 4, 6)
# - (6, 8 , 10)
# - (1, 3, 5)

# %% [markdown]
# Positive example: example that you expected to get answer yes <br>
# Negative example: example that you expected to get answer no
#
# * Positive
# * Negative
# * Negative

# %% [markdown]
# e) Poll 2

# %% [markdown]
# C (1, 2, 3) - Choose the negative example to avoid confirmation bias

# %% [markdown]
# f) Describe steps of a Data Science Workflow

# %% [markdown]
# 0. Figure out the goal (what and who the model is for) and the right tool for their goal (do they need this model?)
# 1. Process Data <br>
#     1.a What to do with missing data/inconsistent data? What data to include and exclude?
# 2. Explore Data
# 3. Extract Features (extract useful attributes from the data set)
# 4. Create Model

# %% [markdown]
# ![Screenshot%202023-09-20%20at%2017.21.24.png](attachment:Screenshot%202023-09-20%20at%2017.21.24.png)

# %% [markdown]
# g) Give a real world example for each of the following data types:
#
# - record
# - graph
# - image
# - text

# %% [markdown]
# * Record: representive as a vector in m-dimentional space. can be tuple, int, etc...
#     * Ex: (name, age, balacne) -> ("John", 20, 100)
# * Graph: nodes connected by edges
#     * Ex: ![Screenshot%202023-09-20%20at%2017.34.43.png](attachment:Screenshot%202023-09-20%20at%2017.34.43.png)
# * Image: pixels
#     * Ex:

# %% [markdown]
# ![Screenshot%202023-09-20%20at%2017.36.00.png](attachment:Screenshot%202023-09-20%20at%2017.36.00.png)

# %% [markdown]
# * Text: Curpus of Documents
#     * Ex: BOG (Bag of Word)

# %% [markdown]
# h) Give a real world example of unsupervised learning

# %% [markdown]
# Unsupervised learning:
# * Goal: find interesting structure in the data
# * Clean the data you have (grouping) - Extract Features
# * improve the data you have: can be used to find substitude for inconsistent/missing data (Data Processing step)
# * Make learning algorithms faster
#
# Ex: Find students who need the most help based on some data like GPA, credits, credits needed, etc...

# %% [markdown]
# i) Give a real world example of supervised learning

# %% [markdown]
# Supervised learning:
# * Goal: make prediction for an unknown data point
#
# Ex: Given the old student data set, predict a new student (based on the new entry) if they need help
